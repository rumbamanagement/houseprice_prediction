# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### The main objective of exploratory data analysis is to see patterns, shapes, relationship and for presenting an immediate impression of everything about the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_houseprice=pd.read_csv("/Users/arjunrumba/Documents/ds_project/houseprice_datapreprocessing.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df_houseprice.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Plotting the distribution curve for the SalePrice

# %%
f, ax = plt.subplots(figsize=(12, 6))
sns.distplot(df_houseprice['SalePrice'])

# %%
predictor = np.log1p(df_houseprice['SalePrice'])
#plotting the distribution curve for the SalePrice
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(predictor)

# %% [markdown]
# ### Data types are checked. It appears that all varaibles have appropriate values.

# %%
data_types=df_houseprice.dtypes.to_frame()
data_types.rename(columns={0:'Data Type'})
# Out:
#               Data Type
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage     float64
# LotArea           int64
# ...                 ...
# MoSold            int64
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
#
# [77 rows x 1 columns]

# %% [markdown]
# ### The variables will be divided into numerical and categorical variables.

# %%
houseprice_categories=df_houseprice[['MSSubClass','MSZoning','Street', 'LotShape','LandContour','Utilities','LotConfig','LandSlope',
              'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle','OverallQual',
              'OverallCond', 'RoofStyle','RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterQual',
              'ExterCond', 'Foundation','BsmtQual', 'BsmtCond','BsmtExposure', 'BsmtFinType1','BsmtFinType2',
              'Heating', 'HeatingQC', 'CentralAir', 'Electrical','KitchenQual','Functional','FireplaceQu',
              'GarageType','GarageFinish','GarageQual', 'GarageCond','PavedDrive','SaleType','SaleCondition']]
houseprice_categories.head()
# Out:
#    MSSubClass MSZoning Street LotShape LandContour Utilities LotConfig  \
# 0          60       RL   Pave      Reg         Lvl    AllPub    Inside
# 1          20       RL   Pave      Reg         Lvl    AllPub       FR2
# 2          60       RL   Pave      IR1         Lvl    AllPub    Inside
# 3          70       RL   Pave      IR1         Lvl    AllPub    Corner
# 4          60       RL   Pave      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond RoofStyle RoofMatl Exterior1st Exterior2nd  \
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Categorical data or qualitative data divides a variable into groups which represents data. Boxplot is used here for visualizing categorical variable. The boxplot displays how categorical variables are associated with target variable 'SalePrice'. It shows mean, median, standard deviaiton,ranges, minimum and maximum values and outliers. Generally, it displays how data are distributed, their relationship with the target variable and helps to study and understand data in meaningful way.

# %%
price=df_houseprice['SalePrice']
for categories in houseprice_categories.columns:

    fig = plt.subplots(figsize=(12,8))
    plt.xticks(rotation=45)

    sns.set(style="whitegrid")
    sns.boxplot(x=categories, y=price, hue=categories, data=houseprice_categories, order=None, 
                hue_order=None, orient=None, color=2, palette='Set3', saturation=1, width=1, dodge=False, 
                fliersize=1, linewidth=2, whis=1.5, ax=None)

# %%
numeric_variable=df_houseprice[['MasVnrArea','LotFrontage','LotArea','YearBuilt','YearRemodAdd',
                       'BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF', '2ndFlrSF',
                       'LowQualFinSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch',
                        '3SsnPorch','ScreenPorch','PoolArea','MiscVal']]
numeric_variable.head()
# Out:
#    MasVnrArea  LotFrontage  LotArea  YearBuilt  YearRemodAdd  BsmtFinSF1  \
# 0       196.0         65.0     8450       2003          2003         706
# 1         0.0         80.0     9600       1976          1976         978
# 2       162.0         68.0    11250       2001          2002         486
# 3         0.0         60.0     9550       1915          1970         216
# 4       350.0         84.0    14260       2000          2000         655
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0           0        150          856       856       854             0
# 1           0        284         1262      1262         0             0
# 2           0        434          920       920       866             0
# 3           0        540          756       961       756             0
# 4           0        490         1145      1145      1053             0
#
#    GrLivArea  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# ...

# %% [markdown]
# ### Histograms for all numeric variables to determine if all variables are skewed.

# %%
#create numeric plots
num = [f for f in numeric_variable.columns if numeric_variable.dtypes[f] != 'object']
nd = pd.melt(numeric_variable, value_vars = num)
n1 = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False)
n1 = n1.map(sns.distplot, 'value')
n1

# %% [markdown]
# ### The scatter plot gives an immediate visualization of the strength and direction of the relationship. It gives visual impression of any deviation from the basic pattern of this relationship. The strength of the association is gauged by how close the plotted points are to a straight line. It is also important to note the outliers.
#
# ### regplot( ) is one of the plot function which shows linear relationship between variables. It is a technique to get insights for regression analysis.

# %%
for numeric in numeric_variable.columns:
    
    sns.set(style="whitegrid")
    fig = plt.subplots(figsize=(10,5))
    plt.xticks(rotation=45)

    sns.regplot(x=numeric, y=price, data=numeric_variable, x_estimator=None, x_bins=None, x_ci='ci', 
                scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None,order=1, logistic=False, robust=False, logx=False, label=None, color=None, marker='o', 
                scatter_kws=None,line_kws=None, ax=None)

# %% [markdown]
# ### MasVnrArea,LotArea, LotFrontage, YearBuilt , BsmtFinSF1, TotalBsmtSF, 1stFlrSF, GrLivArea and GarageArea seems to be strong contender for predicting SalePrice.
#
# ### YearRemodAdd,BsmtFinSF2,BsmtUnfSF,2ndFlrSF, LowQualFinSF, WoodDeckSF, OpenPorchSF, EnclosedPorch, ScreenPorch, PoolArea and MiscVal doesn't seem to be good predictors as the line is close to horizontal and less correlated.

# %% [markdown]
# ### Describe method is used here to understand statistical summaries and measures of data. This will show the count of that variable, the mean, the standard deviation (std),the minimum value, the IQR (Interquartile Range: 25%, 50% and 75%) and the maximum value.

# %%
df_houseprice.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    69.863699   10516.828082     6.099315
# std     421.610009    42.300571    22.027677    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    60.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    79.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.117123   443.639726
# std       1.112799    30.202904     20.645407   180.731373   456.098091
# ...

# %%
df_houseprice.describe(include=['object'])
# Out:
#        MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# count      1460   1460     1460        1460      1460      1460      1460
# unique        5      2        4           4         2         5         3
# top          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# freq       1151   1454      925        1311      1459      1052      1382
#
#        Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# count          1460       1460       1460     1460       1460      1460
# unique           25          9          8        5          8         6
# top           NAmes       Norm       Norm     1Fam     1Story     Gable
# freq            225       1260       1445     1220        726      1141
#
#        RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# count      1460        1460        1460       1460      1460      1460
# unique        8          15          16          5         4         5
# ...

# %% [markdown]
# ### Correlation coefficient is a measure which helps to visually judge the specific strength of a relationship. It measures the dependencies between target variable and independent variables. The coefficeint is the value which falls between -1 and +1 with -1 indicating perfect negative correlation and +1 indicating perfect positive correlation. Correlation doesn't imply correlation.
#
# ### corr( ) computes pairwise correlation of columns, excluding NA/null values.

# %%
df_houseprice.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.009921 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.356718 -0.139781     0.032628
# LotFrontage   -0.009921   -0.356718     1.000000  0.304522     0.234812
# LotArea       -0.033226   -0.139781     0.304522  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.234812  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.053281 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.116685  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.083348  0.013788     0.550684
# MasVnrArea    -0.051071    0.023573     0.178469  0.103321     0.407252
# BsmtFinSF1    -0.005024   -0.069836     0.214367  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.042463  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.124098 -0.002618     0.308159
# ...

# %%
fig = plt.subplots(figsize=(18,9))
plt.xticks(rotation=45)

sns.heatmap(df_houseprice.corr(), vmin=-1, vmax=1, cmap='magma', center=0, robust=True, annot=False,fmt='.2f',
            annot_kws={'size':25}, linewidths=0, linecolor=None, cbar=True, cbar_kws={"shrink": 0.5},
            cbar_ax=None,square=True, xticklabels=True, yticklabels=True, mask=None, ax=None)

# %% [markdown]
# ### The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant. When the p-value is <0.001,  we say there is strong evidence that the correlation is significant. The p-value is<0.05: there is moderate evidence that the correlation is significant. The p-value is <0.1: there is weak evidence that the correlation is significant. The p-value is>0.1: there is no evidence that the correlation is significant.

# %%
import scipy
from scipy import stats

# %% [markdown]
# ### Calculation of Correlation Coefficient and P-value of the numeric variables and the target variable, SalePrice.

# %%
for numeric in numeric_variable:
    pearson_coef, p_value = stats.pearsonr(numeric_variable[numeric], df_houseprice['SalePrice'])
    print(f"\n The Pearson Correlation Coefficient of {numeric} and the target variable SalePrice is {pearson_coef} with a P-value of P = {p_value}")
# Out:
#  The Pearson Correlation Coefficient of MasVnrArea and the target variable SalePrice is 0.47261449900457375 with a P-value of P = 4.100461044539401e-82
#
#  The Pearson Correlation Coefficient of LotFrontage and the target variable SalePrice is 0.33477085313976007 with a P-value of P = 1.4469846007064643e-39
#
#  The Pearson Correlation Coefficient of LotArea and the target variable SalePrice is 0.2638433538714057 with a P-value of P = 1.1231391549193063e-24
#
#  The Pearson Correlation Coefficient of YearBuilt and the target variable SalePrice is 0.5228973328794968 with a P-value of P = 2.9902290990158995e-103
#
#  The Pearson Correlation Coefficient of YearRemodAdd and the target variable SalePrice is 0.5071009671113862 with a P-value of P = 3.1649482419200737e-96
#
#  The Pearson Correlation Coefficient of BsmtFinSF1 and the target variable SalePrice is 0.3864198062421533 with a P-value of P = 3.3941098292907553e-53
#
# ...

# %% [markdown]
# ### Since the p-value of MasVnrArea, LotFrontage, LotArea, YearBuilt, YearRemodAdd, BsmtFinSF1, BsmtUnfSF, TotalBsmtSF,1stFlrSF, 2ndFlrSF,GrLivArea, GarageArea, WoodDeckSF,OpenPorchSF, ScreenPorch, EnclosedPorch and PoolArea are < 0.001, their correlation is statistically significant.

# %% [markdown]
# ### Since the p-value of BsmtFinSF2, LowQualFinSF and MiscVal are > 1, there is no evidence that their correlation is significant.

# %% [markdown]
# ### Since the p-value of 3SsnPorch is <0.1, there is weak evidence that the correlation is significant.

# %% [markdown]
# ### Bar plot makes easier to compare each group of categorical variable.

# %%
for data in houseprice_categories.columns:
    cat_num=houseprice_categories[data].value_counts()
    print("graph for %s: total = %d" % (data,len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for MSSubClass: total = 15
# graph for MSZoning: total = 5
# graph for Street: total = 2
# graph for LotShape: total = 4
# graph for LandContour: total = 4
# graph for Utilities: total = 2
# graph for LotConfig: total = 5
# graph for LandSlope: total = 3
# graph for Neighborhood: total = 25
# graph for Condition1: total = 9
# graph for Condition2: total = 8
# graph for BldgType: total = 5
# graph for HouseStyle: total = 8
# graph for OverallQual: total = 10
# graph for OverallCond: total = 9
# graph for RoofStyle: total = 6
# graph for RoofMatl: total = 8
# graph for Exterior1st: total = 15
# graph for Exterior2nd: total = 16
# graph for MasVnrType: total = 5
# graph for ExterQual: total = 4
# graph for ExterCond: total = 5
# graph for Foundation: total = 6
# graph for BsmtQual: total = 5
# graph for BsmtCond: total = 5
# graph for BsmtExposure: total = 5
# graph for BsmtFinType1: total = 7
# graph for BsmtFinType2: total = 7
# graph for Heating: total = 6
# ...

# %%
df_data=df_houseprice.drop(['BsmtFinSF2', 'LowQualFinSF','MiscVal'], axis=1)
df_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
df_data.to_csv("houseprice_eda.csv", index=0)
